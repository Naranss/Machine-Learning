# %%
# importing libraries
import pandas as pd
import numpy as np
import sklearn as sklearn
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('dataset/steam.csv')
df.shape
# Out:
# (27075, 18)

# %%
df.head(10)
# Out:
#    appid                            name release_date  english  \
# 0     10                  Counter-Strike   2000-11-01        1
# 1     20           Team Fortress Classic   1999-04-01        1
# 2     30                   Day of Defeat   2003-05-01        1
# 3     40              Deathmatch Classic   2001-06-01        1
# 4     50       Half-Life: Opposing Force   1999-11-01        1
# 5     60                        Ricochet   2000-11-01        1
# 6     70                       Half-Life   1998-11-08        1
# 7     80  Counter-Strike: Condition Zero   2004-03-01        1
# 8    130           Half-Life: Blue Shift   2001-06-01        1
# 9    220                     Half-Life 2   2004-11-16        1
#
#           developer publisher          platforms  required_age  \
# 0             Valve     Valve  windows;mac;linux             0
# 1             Valve     Valve  windows;mac;linux             0
# 2             Valve     Valve  windows;mac;linux             0
# ...

# %%
df.drop("appid",axis=1,inplace=True)
df.drop("name",axis=1,inplace=True)
df.drop("developer",axis=1,inplace=True)
df.drop("release_date",axis=1,inplace=True)
df.drop("publisher",axis=1,inplace=True)
df.drop("platforms",axis=1,inplace=True)
df.drop("categories",axis=1,inplace=True)
df.drop("genres",axis=1,inplace=True)
df.drop("steamspy_tags",axis=1,inplace=True)
df.drop("owners",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27075 entries, 0 to 27074
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   english           27075 non-null  int64
#  1   required_age      27075 non-null  int64
#  2   achievements      27075 non-null  int64
#  3   positive_ratings  27075 non-null  int64
#  4   negative_ratings  27075 non-null  int64
#  5   average_playtime  27075 non-null  int64
#  6   median_playtime   27075 non-null  int64
#  7   price             27075 non-null  float64
# dtypes: float64(1), int64(7)
# memory usage: 1.7 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27075 entries, 0 to 27074
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   english           27075 non-null  int64
#  1   required_age      27075 non-null  int64
#  2   achievements      27075 non-null  int64
#  3   positive_ratings  27075 non-null  int64
#  4   negative_ratings  27075 non-null  int64
#  5   average_playtime  27075 non-null  int64
#  6   median_playtime   27075 non-null  int64
#  7   price             27075 non-null  float64
# dtypes: float64(1), int64(7)
# memory usage: 1.7 MB

# %%
df.isnull().sum()
# Out:
# english             0
# required_age        0
# achievements        0
# positive_ratings    0
# negative_ratings    0
# average_playtime    0
# median_playtime     0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3827

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
attribute = df.iloc[:,0:]
attribute
# Out:
#        english  required_age  achievements  positive_ratings  \
# 0            1             0             0            124534
# 1            1             0             0              3318
# 2            1             0             0              3416
# 3            1             0             0              1273
# 4            1             0             0              5250
# ...        ...           ...           ...               ...
# 27050        1             0             7                 2
# 27058        1             0            32                 7
# 27065        1             0             0                 9
# 27067        1             0             0                13
# 27069        1             0             1                 2
#
#        negative_ratings  average_playtime  median_playtime  price
# 0                  3339             17612              317   7.19
# 1                   633               277               62   3.99
# ...

# %%
scaler = StandardScaler()
scaler_attribute = scaler.fit_transform(attribute)

scaler_attribute
# Out:
# array([[ 1.46734080e-01, -1.59472099e-01, -1.37921370e-01, ...,
#          8.84900655e+00,  5.78487509e-02,  8.29502740e-02],
#        [ 1.46734080e-01, -1.59472099e-01, -1.37921370e-01, ...,
#          5.20331778e-02, -4.25689114e-02, -3.01248949e-01],
#        [ 1.46734080e-01, -1.59472099e-01, -1.37921370e-01, ...,
#          6.36097684e-03, -5.35951645e-02, -3.01248949e-01],
#        ...,
#        [ 1.46734080e-01, -1.59472099e-01, -1.37921370e-01, ...,
#         -8.85357073e-02, -6.69841861e-02, -5.29367238e-01],
#        [ 1.46734080e-01, -1.59472099e-01, -1.37921370e-01, ...,
#         -8.85357073e-02, -6.69841861e-02,  3.35081014e-01],
#        [ 1.46734080e-01, -1.59472099e-01, -1.35251189e-01, ...,
#         -8.85357073e-02, -6.69841861e-02, -5.29367238e-01]])
